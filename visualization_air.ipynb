# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
air = pd.read_excel('airquality.xlsx')
air.head()
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
air.shape
# Out:
# (153, 7)

# %%
air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  153 non-null    int64
#  1   Ozone       116 non-null    float64
#  2   Solar.R     146 non-null    float64
#  3   Wind        153 non-null    float64
#  4   Temp        153 non-null    int64
#  5   Month       153 non-null    int64
#  6   Day         153 non-null    int64
# dtypes: float64(3), int64(4)
# memory usage: 8.5 KB

# %%
air.columns
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Month', 'Day'], dtype='object')

# %%
air.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64

# %%
# handling null values 
air['Ozone']=air['Ozone'].fillna(air['Ozone'].mean())

# %%
air.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp          0
# Month         0
# Day           0
# dtype: int64

# %%
air['Solar.R']=air['Solar.R'].fillna(air['Solar.R'].median())

# %%
air.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       0
# Wind          0
# Temp          0
# Month         0
# Day           0
# dtype: int64

# %%
plt.scatter(air['Ozone'], air['Temp'])
plt.xlabel('Ozone')
plt.ylabel('Temperature')
plt.title('Ozone vs Temperature')
plt.show()

# %%
plt.hist(air['Ozone'] , bins=15 ,edgecolor='black')
plt.xlabel('Ozone')
plt.ylabel('Frequency')
plt.title('Ozone Distribution')
plt.show()

# %%
plt.plot(air['Temp'])
plt.xlabel('Index')
plt.ylabel('Temperature')
plt.title('Temperature Trend')
plt.show()

# %%
sns.barplot(x='Month', y='Temp', data=df)
plt.xlabel('Temperature')
plt.ylabel('Month')
plt.title('Bar Plot')
plt.show()

# %%
sns.scatterplot(
    x=air['Ozone'],
    y=air['Temp'],
    hue=air['Month'],
    size=air['Wind']
)
plt.title('Ozone vs Temp with Month & Wind')
plt.show()

# %%
sns.countplot(x='Month', hue='Day', data=air)
plt.title('Month vs Day Count')
plt.show()

# %%
corr=air[['Ozone', 'Solar.R', 'Wind', 'Temp']].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm")
#annot=True --->It means show the actual values inside each cell of the heatmap

plt.title('Correlation Heatmap')
plt.show()

# %%
sns.boxplot(x='Month', y='Ozone', data=air)

plt.title("Ozone by Month")
plt.show()

# %%
air['Month'].value_counts()
# Out:
# Month
# 5    31
# 7    31
# 8    31
# 6    30
# 9    30
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

air['Month'].value_counts().plot.pie(
    autopct='%1.1f%%',
    startangle=120
)

plt.title("Month Distribution in Air Dataset")

plt.show()
